# %%
import aiohttp

# %%
aiohttp.request("GET", "https://pyurl.cc")
# Out:
# /Users/eason/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: RuntimeWarning: coroutine 'ClientSession._request' was never awaited
#   after removing the cwd from sys.path.
# ...
# ERROR:    Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x7ffe1b455c90>
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-9-283da291d83d> in async-def-wrapper()
#
# TypeError: object _SessionRequestContextManager can't be used in 'await' expression

# %%
import aiohttp
import asyncio

AA = []
async def get(url, **kwargs):
    async with aiohttp.ClientSession(**kwargs) as session:
        async with session.get(url, **kwargs) as resp:
            return (await resp.json())

async def post(url, **kwargs):
    async with aiohttp.ClientSession(cookies = {"express:sess.sig": "OBDy-ddc3MyIXhod1c4TgOgwFnc", "express:sess": "eyJ1c2VybmFtZSI6InByaWNlYW4wOEBnbWFpbC5jb20iLCJ0eXBlIjoiYWRtaW4ifQ=="}) as session:
        async with session.post(url, cookies = {"express:sess.sig": "OBDy-ddc3MyIXhod1c4TgOgwFnc", "express:sess": "eyJ1c2VybmFtZSI6InByaWNlYW4wOEBnbWFpbC5jb20iLCJ0eXBlIjoiYWRtaW4ifQ=="}) as resp:
            return (await resp.json())

# %%
result = await post(url= "http://localhost:8080",
           cookies = {"express:sess.sig": "OBDy-ddc3MyIXhod1c4TgOgwFnc",
                      "express:sess": "eyJ1c2VybmFtZSI6InByaWNlYW4wOEBnbWFpbC5jb20iLCJ0eXBlIjoiYWRtaW4ifQ=="})

# %%
result
# Out:
# {'express:sess': 'eyJ1c2VybmFtZSI6InByaWNlYW4wOEBnbWFpbC5jb20iLCJ0eXBlIjoiYWRtaW4ifQ==',
#  'express:sess.sig': 'OBDy-ddc3MyIXhod1c4TgOgwFnc'}

# %%
result = requests.post(url= "http://localhost:8080",
           cookies = {"express:sess.sig": "OBDy-ddc3MyIXhod1c4TgOgwFnc",
                      "express:sess": "eyJ1c2VybmFtZSI6InByaWNlYW4wOEBnbWFpbC5jb20iLCJ0eXBlIjoiYWRtaW4ifQ=="})
result.json()
# Out:
# {'express:sess': 'eyJ1c2VybmFtZSI6InByaWNlYW4wOEBnbWFpbC5jb20iLCJ0eXBlIjoiYWRtaW4ifQ==',
#  'express:sess.sig': 'OBDy-ddc3MyIXhod1c4TgOgwFnc'}

# %%
from aiohttp_requests import requests as aio_requests

# %%
result = await aio_requests.post("https://dev.fio.one/internal-api/fios/LearningCurve",
           cookies = {"express:sess.sig": "OBDy-ddc3MyIXhod1c4TgOgwFnc",
                      "express:sess": "eyJ1c2VybmFtZSI6InByaWNlYW4wOEBnbWFpbC5jb20iLCJ0eXBlIjoiYWRtaW4ifQ=="})

# %%
await result.json()
# Out:
# {'code': 0, 'message': 'ok', 'data': {'user': {}, 'fios': []}}

# %%
result = await aio_requests.post("http://localhost:8080",
           cookies = {"express:sess.sig": "OBDy-ddc3MyIXhod1c4TgOgwFnc",
                      "express:sess": "eyJ1c2VybmFtZSI6InByaWNlYW4wOEBnbWFpbC5jb20iLCJ0eXBlIjoiYWRtaW4ifQ=="})

# %%
await result.json()
# Out:
# {'express:sess': 'eyJ1c2VybmFtZSI6InByaWNlYW4wOEBnbWFpbC5jb20iLCJ0eXBlIjoiYWRtaW4ifQ==',
#  'express:sess.sig': 'OBDy-ddc3MyIXhod1c4TgOgwFnc'}

# %%
import requests

# %%
result = requests.post(url= "https://dev.fio.one/internal-api/fios/LearningCurve",
           cookies = {"express:sess.sig": "OBDy-ddc3MyIXhod1c4TgOgwFnc",
                      "express:sess": "eyJ1c2VybmFtZSI6InByaWNlYW4wOEBnbWFpbC5jb20iLCJ0eXBlIjoiYWRtaW4ifQ=="})

# %%
result.json()
# Out:
# {'code': 0,
#  'message': 'ok',
#  'data': {'user': {'username': 'pricean08@gmail.com', 'type': 'admin'},
#   'fios': [{'id': 900,
#     'name': 'Learning Curve',
#     'solution': 'LearningCurve',
#     'enabled': True,
#     'link': {'form': 'https://docs.google.com/forms/d/1Wao3gOwFMEGiGL1gtGmndFbpN1W5z-om6W81K3QEqqI/viewform',
#      'sheet': 'https://docs.google.com/spreadsheets/d/1rigx9VWLgT-RWVziFEUPNsZI79VAvlAJc5UgazeZzoI'},
#     'code': "async (contract) => {\n  // initiate data object\n  var obj = contract.obj;\n  var fio = contract.fio;\n  var msg = obj.dict(fio.input);\n\n  // stringify JSON object and sign with GPG\n  var signed = await contract.GPG_sign(JSON.stringify(msg));\n\n  // publish cipher to IOTA\n  var bundle = await contract.IOTA_send(signed);\n  var hash = bundle.map(x => x.hash).join('+');\n  await contract.db.add('iota_log', {date: new Date(), obj_id: obj.obj_id, hash, msg});\n\n  // update Google Sheet\n  await obj.set(fio.output.Hash, hash);\n}",
# ...

# %%
def get_user_email_by_cookies(cookies):
    url = "https://dev.fio.one/internal-api/fios/LearningCurve"

    result = requests.post(url, cookies = cookies)

    return result.json()["data"]["user"]["username"]

# %%
await get(url = 'https://fio5.ntnu.best/nodesStatus', 
          headers = {"hi", "QQ"})
# Out:
# {'node': {'LMI': 3368150,
#   'LSMI': 3214251,
#   'isSynced': False,
#   'lossSync': False,
#   'neighbors': 1,
#   'official_LMI': 3368149,
#   'status': 'online',
#   'url': 'https://node.fio.one',
#   'useable': False}}

# %%
kwargs = AA[0]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-37-b06b1879bfb6> in <module>
# ----> 1 kwargs = AA[0]
#
# IndexError: list index out of range

# %%
def hi(a):
    print(a)
